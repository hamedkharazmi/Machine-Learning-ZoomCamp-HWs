# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv('heart_statlog_cleveland_hungary_final.csv')
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
samples = df.sample(n=5)
samples
# Out:
#       age  sex  chest_pain_type  resting_bp_s  cholesterol  \
# 1116   66    1                4           112          212
# 1122   54    1                4           122          286
# 935    65    0                3           140          417
# 1120   74    0                2           120          269
# 688    57    0                4           120          354
#
#       fasting_blood_sugar  resting_ecg  max_heart_rate  exercise_angina  \
# 1116                    0            2             132                1
# 1122                    0            2             116                1
# 935                     1            2             157                0
# 1120                    0            2             121                1
# 688                     0            0             163                1
#
#       oldpeak  st_slope  target
# 1116      0.1         1       1
# 1122      3.2         2       1
# 935       0.8         1       0
# 1120      0.2         1       0
# 688       0.6         1       0

# %%
# url = 'http://localhost:9696/predict'
url = 'https://heart-disease-pred-service.herokuapp.com/predict'

for sample in samples.apply(lambda x: json.loads(x.to_json()), axis=1):
    val = sample.pop('heartdisease', None)
    response = requests.post(url, json=sample).json()
    print(response, val)
# Out:
# {'heartdisease': True, 'heartdisease_probability': 0.7443079352378845} None
# {'heartdisease': True, 'heartdisease_probability': 0.9882708191871643} None
# {'heartdisease': False, 'heartdisease_probability': 0.10818973928689957} None
# {'heartdisease': False, 'heartdisease_probability': 0.05808323621749878} None
# {'heartdisease': False, 'heartdisease_probability': 0.07916247844696045} None
